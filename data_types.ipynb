# %% [markdown]
# #### Data type:
# ##### classification of the data that tells the compiler or the interpretter that what kind of value  we can store into a var and how much amt of memory can be consumed to store the data and the operation it can pwrform
#
#
# #### Data types are classification of the data that tells the compiler or the interpreter that what kind of value we can store into a var and how much amt of memory will be consume to store the data and the operations it can perform

# %%
# Take num as a input convert theat num into int.
weight = input("Enter your weight plz")
print(weight)
print(type(weight))
#print(weight +10)  # show error bcz input is str so make it int
print(int(weight)+10)
w = int(weight)
print(type(w))
# Out:
# 75
# <class 'str'>
# 85
# <class 'int'>

# %%
# Convert directly into int
weight = int(input("Enter your age"))
print(weight)
print(type(weight))
# Out:
# 75
# <class 'int'>

# %% [markdown]
# #### 1. Upcasting
# ###### smaaller data type -> larger data type, python does not do it automatically

# %%
expense_in_march = 75
print(expense_in_march)
print(type(expense_in_march))
# Out:
# 75
# <class 'int'>

# %%
expense_in_march = 75
expense_in_march
# Out:
# 75
