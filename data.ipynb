# %% [markdown]
# ## Data

# %% [markdown]
# → Data is collection of raw facts and value that can be proccessed to get meaningfull information. Ex.
#
# 23
# Abhishek
# 11001
# cannaught place
# New Delhhi
#
# → after processing of data:
# Employee name: Abhishek
# age: 23
# office address: cannaught plave, New Delhi 110001
#
# ---
# Data vs Information:
#
# → Data: Row fact, no meaning, input, unorganized
#
# → Information: Processed data, Meaningful, output , Organized
#
# ---
# Typ of data:
#
# 1. Structured Data: Stored in row and columns ex - mysql, postgresql, orace.
#
# | ID | Name | Amount |
# |----|------|--------|
# | 1 | Abhishek | 5000 |
#
# 2. Semi Structured Data:
#  No fixed table format. ex -
#  JSON,XML,HTML
#
# ```json
#
# {
#     "name":"Abhishek",
#     "age":25
# }
# ```
#
# 3. Unstructured Data:
# No fixed Str. ex -
# img,vid,aud,pdf,email, social media pots etc
# → LLM mostly work with unstructured data.
#
# ---
# Qualitative vs Quantitative Data:
#
# Qualitative: Descriptive
# ex. Color , Gender, City
#
# → Quantitative: Numeric
# ex. Salary, Height, Weight
#
# ---
# → Categotrical Data:
# Male, Female, Red , Blue, Green etc
#
# ---
#
# → Numerical Data: 10,20,100 etc
#
# ---
# → Continuous Data: Measured.
# Height, Weight, Temp
#
# ---
# → Time Series Data: Data collected over time.
# | Month | Sales |
# |-------|-------|
# |Jan    | 120   |
# |Feb    | 140   |
#
# ---
# → Big Data: Large Amt of data. ex.
# Facebook, youtube, amazon, netflix
#
# ---
# → 5Vs of Big Data:
# Volume, Velocity, Veriety, Veracity, value.
#
# ---
# → Dataset: Collection of data. Ex.
# employee.csv
#
# ---
# → Features: Input Columns. Ex.
# |Age|Salary|Exp|
# these are the features
#
# ---
# → Label: output column. Ex.
# |Purchased|
# Machine learning predicts the label.
#
# ---
# → Record: one row.
#
# ---
# → Observation: same as record.
#
# ---
# → Sample: Small part of population.
#
# ---
#
# → Population: Entire Data. Ex.
#
# ---
# → Missing Data: Ex.
# |Name| Salary  |
# |----|---------|
# |Abhishek|1.5|
# |Aryan  | NULL|
#
# handling methods:
# Remove rows
# - Fill Means
# - Fill Median
# - Fill Mode
# ---
# → Dublicate Data: Same reccord repeated.
# - Need to remove duplicates.
# ---
# → Outliers: Very different values. Ex.
# - 20
# - 22
# - 24
# - 500
# here 500 is a outlier.
#
# ---
# → Noise: Wrong Data. Ex.
# Age = 190
#
# ---
# → Balanced Dataset: Both classes nearly equal. Ex.
# yes = 500
# no = 480
#
# ---
# → Imbalanced Dataset:
# yes = 980
# no = 20
#
# ---
# → Training Data: Used for learning.
#
# ---
# → Validation Data: Used for tuning hyperparameters.
#
# ---
# → Test Data: Used for final evaluation.
#
# ---
# → Data Cleaning: Task includes-
# - Remove duplicates
# - Handle missing values
# - Correct data types
# - Remove outliers
# - Fixed inconsistent values
#
# ---
# → Data Processing: includes -
# - Cleaning
# - Encoding
# - Scaling
# - Spitting
# - Feature engineering
# ---
# → Feature Engineering: Creating better input features. Ex.
# Date
# converted into - day, month, year, weekend.
#
# ---
# → Feature Selection: Choose only usefull features
#
# ---
# → Data Encoding: Convert Categorical data to numbers. Ex.
# - Label Encoding
# - One ot Encoding
#
# ---
# → Data Scaling: Normalize feature value
# Methods:
# - Min-Max Scaling
# - Standarization
#
# ---
# → Data Normalization: Range bw 0 and 1.
# ---
# → Standerization:
# Mean = 0
# Standered Derivatives = 1
#
# ---
# → Data Pipeline:
# Collect Data -> Clean Data-> Preprocess-> Train Model->Evaluate-> Deploy
#
# ---
# → Data Augmentation: Create more training data. Ex.
# - Rotate Img
# - Flip img
# - Add noise
# - Crop img
# ---
# → Data Annotation: Adding labels to data. Ex.
# Image -> Cat
#
# ---
# → Data Drift: When real world data changes over time, causing model performance to degrade.
#
# ---
# → Data Leakage: When information from the future or test data accidently reaches the training process, leading to unrealistically high accuracy.
