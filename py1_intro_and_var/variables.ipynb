# %% [markdown]
# ###### how to use  .ipynb
# 1. create file with extension .ipynb
# 2. install python env in vscode t use it
# 3. markdown: for writing heading or definition use single # to ###### . they work in incr order
# 4. code: use code option and write code insie them
# 5. Hit run btn: to run code hit it or use shortcut key shift+enter

# %% [markdown]
# ## Variables
# #### variables are the element that can be used for storing data in memory. we create a var by assigning a value using == operator
# #### name = 'Abhishek' here name is variable which atore object 8

# %%
name = "Abhishek"
age = 30
weight = 75

# %%
name = 'Abhishek'
weight = 75
height = 6

# %%
name
# Out:
# 'Abhishek'

# %%
height
# Out:
# 6

# %%
weight
# Out:
# 75

# %% [markdown]
# ## print():
# ####  built in python funused to display output on the screen or consolw. it used to see var value , msg and prog result during exception
#
# ## return()
# #### return is used to send value back from a function

# %%
def add(a,b):
    return a+b
#return will gives the value back a+b
result = add(10,10)

# printdisplay it
print(result)
# Out:
# 20

# %% [markdown]
# ##### Var stores a val in memory so that it can be used latter in  proggram.
# #### Do we need var? yes without var : print("Abhi") but with var we will write name = 'Abhi' print(name) so benifits is ki - reusability, readai\bility, easy mainenance, dynamic programing
# #### any data typ we can stor in var like integer, boolean, float etc
# ### 1. Check Data Type of Var :

# %%
name1 = 'Abhi'
weight = 75.5
height = 6

print(type(name1))
print(type(weight))
print(type(height))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %% [markdown]
# #### 2. Dynamic Typing

# %%
# no data type dec req. python automatically detects type.
name = 'Abhi'
print(name)
val = 10
print(type(val))
# Out:
# Abhi
# <class 'int'>

# %% [markdown]
# #### 3. Var Reassign

# %%
# old val is replaced
name = 'Abhi'
print(name)
name ="aryan"
print(name)
print(name)
# Out:
# Abhi
# aryan
# aryan

# %% [markdown]
# #### 4. multiple assignment

# %%
x,y,z = 10,20,30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %% [markdown]
# #### 5. Memory Ref concept

# %%
x = 10
# var does not store value directly, it refrence to a object

# %% [markdown]
# #### Comment: is the statement in a program that we do not want to execute or intercept

# %% [markdown]
# #### intercept: executes the code  line by line in python
# #### compiler: execute the code completely

# %%
''' 
this is not real comment , it is multiline string buddy  '''
# this is single line comment
# Out:
# ' \nthis is not real comment , it is multiline string buddy  '

# %% [markdown]
# #### 6. naming convention: standered way to keep code clean, readble and professional. it follow PEP8 guidelined.

# %%
# sname_case
userName = 'Abhi'
#should be meaningfull
x = "Abhi" #not meaningfull
#use lowercase letter: Name dont use
#use underscore bw words
first_name = "Abhi"
last_name  = 'Aryan'
#var name should sound like question
is_active = True
is_logged_in = False
has_permission = True
#constants use UPPER_CASE
PI = 3.14
MAX_USERS = 100
API_KEY = 'xx09ju77779000ojdjjjlsllllllllllnfff6878dfdfgdg'
#dont use keywords like: for,if,class
#dont use single letters: a = "Abhi"
#Ai naming con:
prompt = "Explain AI"
user_query = "what is RAG?"
chat_history = []

# %% [markdown]
# #### type casting: onvert 1 data typ intoanother data type . python provide  built-in fun like int(), float() , str() and bool() for this purpose

# %% [markdown]
# #### why type casting:

# %%
age = "25"
print(age)
# print(age + 5) typeError
# so to resolve any data type conflict we use typcasting
print(int(age)+5)

#name = int(input("Enter your name"))
#name = str(input("Enter your name"))
name = bool(input("Enter your name"))

print((name))
print(type(name))
# Out:
# 25
# 30
# True
# <class 'bool'>
